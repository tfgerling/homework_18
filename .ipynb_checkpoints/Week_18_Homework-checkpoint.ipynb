# %% [markdown]
# ## Week 18 - Intro to Neural Networks
#
# ### 1.	What is a neural network? What are the general steps required to build a neural network?

# %% [markdown]
# Neural networks - process that mimics the human brain to understand patterns in data. These were inspired by biological neural networks. Neural networks learn to perform tasks by being exposed to various datasets and examples without any task-specific rules. These networks learn via supervised learning.

# %% [markdown]
# - 1. Prepare the data set (source of information for the problem)
# - 2. Choose a correct neural network architecture
# - 3. Set the training strategy
# - 4. Set the model selection
# - 5. Evaluate the model
# - 6. Deploy the model (make predictions)

# %% [markdown]
# ### 2.	Generally, how do you check the performance of a neural network? Why?

# %% [markdown]
# In order to check the performance of a neural network, you want to evaluate the loss (alculated using the network's output predictions and the true labels for the respective input).

# %% [markdown]
# We want to minimize the loss function to have a better model so need to check it first.

# %% [markdown]
# ### 3.	Create a neural network using keras to predict the outcome of either of these datasets:
# Cardiac Arrhythmia: https://archive.ics.uci.edu/ml/datasets/Arrhythmia
#
# Abalone age: https://archive.ics.uci.edu/ml/datasets/Abalone

# %%
# importing libraries
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("arrhythmia_csv.csv")
df.head()
# Out:
#    age  sex  height  weight  QRSduration  PRinterval  Q-Tinterval  Tinterval  \
# 0   75    0     190      80           91         193          371        174
# 1   56    1     165      64           81         174          401        149
# 2   54    0     172      95          138         163          386        185
# 3   55    0     175      94          100         202          380        179
# 4   75    0     190      80           88         181          360        177
#
#    Pinterval  QRS  ...  chV6_QwaveAmp  chV6_RwaveAmp  chV6_SwaveAmp  \
# 0        121  -16  ...            0.0            9.0           -0.9
# 1         39   25  ...            0.0            8.5            0.0
# 2        102   96  ...            0.0            9.5           -2.4
# 3        143   28  ...            0.0           12.2           -2.2
# 4        103  -16  ...            0.0           13.1           -3.6
#
#    chV6_RPwaveAmp  chV6_SPwaveAmp  chV6_PwaveAmp  chV6_TwaveAmp  chV6_QRSA  \
# 0             0.0               0            0.9            2.9       23.3
# 1             0.0               0            0.2            2.1       20.4
# 2             0.0               0            0.3            3.4       12.3
# 3             0.0               0            0.4            2.6       34.6
# 4             0.0               0           -0.1            3.9       25.4
#
#    chV6_QRSTA  class
# 0        49.4      8
# 1        38.8      6
# 2        49.0     10
# 3        61.6      1
# 4        62.8      7
#
# [5 rows x 280 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Columns: 280 entries, age to class
# dtypes: float64(121), int64(159)
# memory usage: 988.9 KB

# %% [markdown]
# Check on the number of nulls and get them taken care of using interpolate.

# %%
df.isna().values.sum()
# Out:
# 408

# %%
df.interpolate (method='polynomial', order=1, axis=0, limit_area='inside', inplace=True)

# %%
df.isna().values.sum()
# Out:
# 3

# %%
df.interpolate(method='linear', limit_direction = 'backward', inplace=True)

# %%
df.isna().values.sum()
# Out:
# 1

# %%
df.interpolate(method='linear', limit_direction = 'forward', inplace=True)

# %%
df.isna().values.sum()
# Out:
# 0

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 280 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    age                           int64
#  1    sex                           int64
#  2    height                        int64
#  3    weight                        int64
#  4    QRSduration                   int64
#  5    PRinterval                    int64
#  6    Q-Tinterval                   int64
#  7    Tinterval                     int64
#  8    Pinterval                     int64
#  9    QRS                           int64
#  10   T                             float64
#  11   P                             float64
#  12   QRST                          float64
#  13   J                             float64
#  14   heartrate                     float64
#  15   chDI_Qwave                    int64
#  16   chDI_Rwave                    int64
#  17   chDI_Swave                    int64
#  18   chDI_RPwave                   int64
#  19   chDI_SPwave                   int64
#  20   chDI_intrinsicReflecttions    int64
#  21   chDI_RRwaveExists             int64
#  22   chDI_DD_RRwaveExists          int64
#  23   chDI_RPwaveExists             int64
#  24   chDI_DD_RPwaveExists          int64
#  25   chDI_RTwaveExists             int64
#  26   chDI_DD_RTwaveExists          int64
#  27   chDII_Qwave                   int64
#  28   chDII_Rwave                   int64
#  29   chDII_Swave                   int64
#  30   chDII_RPwave                  int64
#  31   chDII_SPwave                  int64
#  32   chDII_intrinsicReflecttions   int64
#  33   chDII_RRwaveExists            int64
#  34   chDII_DD_RRwaveExists         int64
#  35   chDII_RPwaveExists            int64
#  36   chDII_DD_RPwaveExists         int64
#  37   chDII_RTwaveExists            int64
#  38   chDII_DD_RTwaveExists         int64
#  39   chDIII_Qwave                  int64
#  40   chDIII_Rwave                  int64
#  41   chDIII_Swave                  int64
#  42   chDIII_RPwave                 int64
#  43   chDIII_SPwave                 int64
#  44   chDIII_intrinsicReflecttions  int64
#  45   chDIII_RRwaveExists           int64
#  46   chDIII_DD_RRwaveExists        int64
#  47   chDIII_RPwaveExists           int64
#  48   chDIII_DD_RPwaveExists        int64
#  49   chDIII_RTwaveExists           int64
#  50   chDIII_DD_RTwaveExists        int64
#  51   chAVR_Qwave                   int64
#  52   chAVR_Rwave                   int64
#  53   chAVR_Swave                   int64
#  54   chAVR_RPwave                  int64
#  55   chAVR_SPwave                  int64
#  56   chAVR_intrinsicReflecttions   int64
#  57   chAVR_RRwaveExists            int64
#  58   chAVR_DD_RRwaveExists         int64
#  59   chAVR_RPwaveExists            int64
#  60   chAVR_DD_RPwaveExists         int64
#  61   chAVR_RTwaveExists            int64
#  62   chAVR_DD_RTwaveExists         int64
#  63   chAVL_Qwave                   int64
#  64   chAVL_Rwave                   int64
#  65   chAVL_Swave                   int64
#  66   chAVL_RPwave                  int64
#  67   chAVL_SPwave                  int64
#  68   chAVL_intrinsicReflecttions   int64
#  69   chAVL_RRwaveExists            int64
#  70   chAVL_DD_RRwaveExists         int64
#  71   chAVL_RPwaveExists            int64
#  72   chAVL_DD_RPwaveExists         int64
#  73   chAVL_RTwaveExists            int64
#  74   chAVL_DD_RTwaveExists         int64
#  75   chAVF_Qwave                   int64
#  76   chAVF_Rwave                   int64
#  77   chAVF_Swave                   int64
#  78   chAVF_RPwave                  int64
#  79   chAVF_SPwave                  int64
#  80   chAVF_intrinsicReflecttions   int64
#  81   chAVF_RRwaveExists            int64
#  82   chAVF_DD_RRwaveExists         int64
#  83   chAVF_RPwaveExists            int64
#  84   chAVF_DD_RPwaveExists         int64
#  85   chAVF_RTwaveExists            int64
#  86   chAVF_DD_RTwaveExists         int64
#  87   chV1_Qwave                    int64
#  88   chV1_Rwave                    int64
#  89   chV1_Swave                    int64
#  90   chV1_RPwave                   int64
#  91   chV1_SPwave                   int64
#  92   chV1_intrinsicReflecttions    int64
#  93   chV1_RRwaveExists             int64
#  94   chV1_DD_RRwaveExists          int64
#  95   chV1_RPwaveExists             int64
#  96   chV1_DD_RPwaveExists          int64
#  97   chV1_RTwaveExists             int64
#  98   chV1_DD_RTwaveExists          int64
#  99   chV2_Qwave                    int64
#  100  chV2_Rwave                    int64
#  101  chV2_Swave                    int64
#  102  chV2_RPwave                   int64
#  103  chV2_SPwave                   int64
#  104  chV2_intrinsicReflecttions    int64
#  105  chV2_RRwaveExists             int64
#  106  chV2_DD_RRwaveExists          int64
#  107  chV2_RPwaveExists             int64
#  108  chV2_DD_RPwaveExists          int64
#  109  chV2_RTwaveExists             int64
#  110  chV2_DD_RTwaveExists          int64
#  111  chV3_Qwave                    int64
#  112  chV3_Rwave                    int64
#  113  chV3_Swave                    int64
#  114  chV3_RPwave                   int64
#  115  chV3_SPwave                   int64
#  116  chV3_intrinsicReflecttions    int64
#  117  chV3_RRwaveExists             int64
#  118  chV3_DD_RRwaveExists          int64
#  119  chV3_RPwaveExists             int64
#  120  chV3_DD_RPwaveExists          int64
#  121  chV3_RTwaveExists             int64
#  122  chV3_DD_RTwaveExists          int64
#  123  chV4_Qwave                    int64
#  124  chV4_Rwave                    int64
#  125  chV4_Swave                    int64
#  126  chV4_RPwave                   int64
#  127  chV4_SPwave                   int64
#  128  chV4_intrinsicReflecttions    int64
#  129  chV4_RRwaveExists             int64
#  130  chV4_DD_RRwaveExists          int64
#  131  chV4_RPwaveExists             int64
#  132  chV4_DD_RPwaveExists          int64
#  133  chV4_RTwaveExists             int64
#  134  chV4_DD_RTwaveExists          int64
#  135  chV5_Qwave                    int64
#  136  chV5_Rwave                    int64
#  137  chV5_Swave                    int64
#  138  chV5_RPwave                   int64
#  139  chV5_SPwave                   int64
#  140  chV5_intrinsicReflecttions    int64
#  141  chV5_RRwaveExists             int64
#  142  chV5_DD_RRwaveExists          int64
#  143  chV5_RPwaveExists             int64
#  144  chV5_DD_RPwaveExists          int64
#  145  chV5_RTwaveExists             int64
#  146  chV5_DD_RTwaveExists          int64
#  147  chV6_Qwave                    int64
#  148  chV6_Rwave                    int64
#  149  chV6_Swave                    int64
#  150  chV6_RPwave                   int64
#  151  chV6_SPwave                   int64
#  152  chV6_intrinsicReflecttions    int64
#  153  chV6_RRwaveExists             int64
#  154  chV6_DD_RRwaveExists          int64
#  155  chV6_RPwaveExists             int64
#  156  chV6_DD_RPwaveExists          int64
#  157  chV6_RTwaveExists             int64
#  158  chV6_DD_RTwaveExists          int64
#  159  chDI_JJwaveAmp                float64
#  160  chDI_QwaveAmp                 float64
#  161  chDI_RwaveAmp                 float64
#  162  chDI_SwaveAmp                 float64
#  163  chDI_RPwaveAmp                float64
#  164  chDI_SPwaveAmp                int64
#  165  chDI_PwaveAmp                 float64
#  166  chDI_TwaveAmp                 float64
#  167  chDI_QRSA                     float64
#  168  chDI_QRSTA                    float64
#  169  chDII_JJwaveAmp               float64
#  170  chDII_QwaveAmp                float64
#  171  chDII_RwaveAmp                float64
#  172  chDII_SwaveAmp                float64
#  173  chDII_RPwaveAmp               float64
#  174  chDII_SPwaveAmp               float64
#  175  chDII_PwaveAmp                float64
#  176  chDII_TwaveAmp                float64
#  177  chDII_QRSA                    float64
#  178  chDII_QRSTA                   float64
#  179  chDIII_JJwaveAmp              float64
#  180  chDIII_QwaveAmp               float64
#  181  chDIII_RwaveAmp               float64
#  182  chDIII_SwaveAmp               float64
#  183  chDIII_RPwaveAmp              float64
#  184  chDIII_SPwaveAmp              float64
#  185  chDIII_PwaveAmp               float64
#  186  chDIII_TwaveAmp               float64
#  187  chDIII_QRSA                   float64
#  188  chDIII_QRSTA                  float64
#  189  chAVR_JJwaveAmp               float64
#  190  chAVR_QwaveAmp                float64
#  191  chAVR_RwaveAmp                float64
#  192  chAVR_SwaveAmp                float64
#  193  chAVR_RPwaveAmp               float64
#  194  chAVR_SPwaveAmp               float64
#  195  chAVR_PwaveAmp                float64
#  196  chAVR_TwaveAmp                float64
#  197  chAVR_QRSA                    float64
#  198  chAVR_QRSTA                   float64
#  199  chAVL_JJwaveAmp               float64
#  200  chAVL_QwaveAmp                float64
#  201  chAVL_RwaveAmp                float64
#  202  chAVL_SwaveAmp                float64
#  203  chAVL_RPwaveAmp               float64
#  204  chAVL_SPwaveAmp               int64
#  205  chAVL_PwaveAmp                float64
#  206  chAVL_TwaveAmp                float64
#  207  chAVL_QRSA                    float64
#  208  chAVL_QRSTA                   float64
#  209  chAVF_JJwaveAmp               float64
#  210  chAVF_QwaveAmp                float64
#  211  chAVF_RwaveAmp                float64
#  212  chAVF_SwaveAmp                float64
#  213  chAVF_RPwaveAmp               float64
#  214  chAVF_SPwaveAmp               float64
#  215  chAVF_PwaveAmp                float64
#  216  chAVF_TwaveAmp                float64
#  217  chAVF_QRSA                    float64
#  218  chAVF_QRSTA                   float64
#  219  chV1_JJwaveAmp                float64
#  220  chV1_QwaveAmp                 float64
#  221  chV1_RwaveAmp                 float64
#  222  chV1_SwaveAmp                 float64
#  223  chV1_RPwaveAmp                float64
#  224  chV1_SPwaveAmp                float64
#  225  chV1_PwaveAmp                 float64
#  226  chV1_TwaveAmp                 float64
#  227  chV1_QRSA                     float64
#  228  chV1_QRSTA                    float64
#  229  chV2_JJwaveAmp                float64
#  230  chV2_QwaveAmp                 float64
#  231  chV2_RwaveAmp                 float64
#  232  chV2_SwaveAmp                 float64
#  233  chV2_RPwaveAmp                float64
#  234  chV2_SPwaveAmp                float64
#  235  chV2_PwaveAmp                 float64
#  236  chV2_TwaveAmp                 float64
#  237  chV2_QRSA                     float64
#  238  chV2_QRSTA                    float64
#  239  chV3_JJwaveAmp                float64
#  240  chV3_QwaveAmp                 float64
#  241  chV3_RwaveAmp                 float64
#  242  chV3_SwaveAmp                 float64
#  243  chV3_RPwaveAmp                float64
#  244  chV3_SPwaveAmp                float64
#  245  chV3_PwaveAmp                 float64
#  246  chV3_TwaveAmp                 float64
#  247  chV3_QRSA                     float64
#  248  chV3_QRSTA                    float64
#  249  chV4_JJwaveAmp                float64
#  250  chV4_QwaveAmp                 float64
#  251  chV4_RwaveAmp                 float64
#  252  chV4_SwaveAmp                 float64
#  253  chV4_RPwaveAmp                float64
#  254  chV4_SPwaveAmp                float64
#  255  chV4_PwaveAmp                 float64
#  256  chV4_TwaveAmp                 float64
#  257  chV4_QRSA                     float64
#  258  chV4_QRSTA                    float64
#  259  chV5_JJwaveAmp                float64
#  260  chV5_QwaveAmp                 float64
#  261  chV5_RwaveAmp                 float64
#  262  chV5_SwaveAmp                 float64
#  263  chV5_RPwaveAmp                float64
#  264  chV5_SPwaveAmp                int64
#  265  chV5_PwaveAmp                 float64
#  266  chV5_TwaveAmp                 float64
#  267  chV5_QRSA                     float64
#  268  chV5_QRSTA                    float64
#  269  chV6_JJwaveAmp                float64
#  270  chV6_QwaveAmp                 float64
#  271  chV6_RwaveAmp                 float64
#  272  chV6_SwaveAmp                 float64
#  273  chV6_RPwaveAmp                float64
#  274  chV6_SPwaveAmp                int64
#  275  chV6_PwaveAmp                 float64
#  276  chV6_TwaveAmp                 float64
#  277  chV6_QRSA                     float64
#  278  chV6_QRSTA                    float64
#  279  class                         int64
# dtypes: float64(121), int64(159)
# memory usage: 988.9 KB

# %%
df['class'].value_counts()
# Out:
# 1     245
# 10     50
# 2      44
# 6      25
# 16     22
# 3      15
# 4      15
# 5      13
# 9       9
# 15      5
# 14      4
# 7       3
# 8       2
# Name: class, dtype: int64

# %% [markdown]
# The class column is the one that indicates whether there is a heart condition or not. Given that there are many different values, I'm using lambda to change the 1's to 0's (which indicate no heart issue), and everything else to 1's (to indicate a heart issue).

# %%
df['class'] = df['class'].apply(lambda x: 0 if x==1 else 1)

# %%
df['class'].value_counts()
# Out:
# 0    245
# 1    207
# Name: class, dtype: int64

# %% [markdown]
# #### Now begin with keras to predict outcomes

# %%
from keras.layers import Dense
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = df.drop('class', axis=1).values
y = df['class'].values

# Split into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42, stratify=y)

# Standardize
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

n_cols = X_train.shape[1]

# %%
import tensorflow as tf
tf.random.set_seed(42)

from keras.optimizers import gradient_descent_v2 

# define the keras model
model = Sequential()
model.add(Dense(500, activation='relu', input_shape = (n_cols,)))
model.add(Dense(250, activation='relu'))
model.add(Dense(250, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1))

# compile the keras model
#optim = gradient_descent_v2.SGD(learning_rate=0.01)
#model.compile(loss='binary_crossentropy', optimizer=optim, metrics=['accuracy'])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size = 128, epochs = 20, verbose = 1, validation_data = (X_test, y_test))
#model.fit(X_train, y_train, validation_data = (X_test, y_test))
#model.fit(X_train, y_train, batch_size = 128, verbose = 1)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 1s 61ms/step - loss: 2.0670 - accuracy: 0.5538 - val_loss: 0.8297 - val_accuracy: 0.6912
# Epoch 2/20
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7095 - accuracy: 0.6994 - val_loss: 0.5578 - val_accuracy: 0.6985
# Epoch 3/20
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5170 - accuracy: 0.7089 - val_loss: 0.4947 - val_accuracy: 0.7500
# Epoch 4/20
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4521 - accuracy: 0.8101 - val_loss: 0.8700 - val_accuracy: 0.7500
# Epoch 5/20
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3377 - accuracy: 0.8797 - val_loss: 0.4942 - val_accuracy: 0.7794
# Epoch 6/20
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2777 - accuracy: 0.8513 - val_loss: 0.6992 - val_accuracy: 0.7574
# Epoch 7/20
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1999 - accuracy: 0.9114 - val_loss: 1.0012 - val_accuracy: 0.7132
# Epoch 8/20
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1986 - accuracy: 0.9494 - val_loss: 0.9040 - val_accuracy: 0.7279
# Epoch 9/20
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1225 - accuracy: 0.9684 - val_loss: 1.6585 - val_accuracy: 0.7574
# Epoch 10/20
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0933 - accuracy: 0.9810 - val_loss: 1.5711 - val_accuracy: 0.7500
# Epoch 11/20
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0740 - accuracy: 0.9937 - val_loss: 1.5321 - val_accuracy: 0.7426
# Epoch 12/20
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0576 - accuracy: 0.9968 - val_loss: 1.9528 - val_accuracy: 0.7868
# Epoch 13/20
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0523 - accuracy: 0.9968 - val_loss: 2.3220 - val_accuracy: 0.7794
# Epoch 14/20
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0488 - accuracy: 0.9968 - val_loss: 2.3409 - val_accuracy: 0.7721
# Epoch 15/20
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0483 - accuracy: 0.9968 - val_loss: 2.3481 - val_accuracy: 0.7794
# Epoch 16/20
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0483 - accuracy: 0.9968 - val_loss: 2.5256 - val_accuracy: 0.7794
# Epoch 17/20
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0483 - accuracy: 0.9968 - val_loss: 2.5280 - val_accuracy: 0.7868
# Epoch 18/20
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0483 - accuracy: 0.9968 - val_loss: 2.6094 - val_accuracy: 0.7868
# Epoch 19/20
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0483 - accuracy: 0.9968 - val_loss: 2.6098 - val_accuracy: 0.7868
# Epoch 20/20
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0483 - accuracy: 0.9968 - val_loss: 2.6131 - val_accuracy: 0.7868

# %%
score, acc = model.evaluate(X_test, y_test, verbose=0)

# %%
print('score', score)
print('accuracy', acc)
# Out:
# score 2.6131432056427
# accuracy 0.7867646813392639

# %% [markdown]
# ### 4.	Write another algorithm to predict the same result as the previous question using either KNN or logistic regression.

# %% [markdown]
# Using KNN, predict accuracy.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

X = df.drop('class', axis=1).values
y = df['class'].values

# Split into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state=42, stratify=y)

# Standardize
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
def kfunc():
    ### find the best k value ###
    #initialize k prior to while loop
    k=1
    
    #set score1 and k1 to 0 - they will be used to hold maximum value
    score1 = 0
    k1 = 0
    
    #start while loop at 1 and increment by 2 (using just odd numbers)
    while (k < 40):
        knn=KNeighborsClassifier(n_neighbors=k)
        knn.fit(X_train, y_train)
        y_predict = knn.predict(X_test)
        score = knn.score(X_test,y_test)
        
        #if saved score is lower than score just calculated, save the new one. Save the corresponding k as well
        if score1 < score:
            score1 = score
            k1 = k
        k += 2
        
    return k1,score1

kfunc()
# Out:
# (3, 0.6243093922651933)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

#use k from above function
knn = KNeighborsClassifier(n_neighbors=3,leaf_size=40,algorithm='kd_tree')
knn.fit(X_train,y_train)
pred = knn.predict(X_test)
print(accuracy_score(y_test, pred))
# Out:
# 0.6243093922651933

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.93      0.73        98
#            1       0.76      0.27      0.39        83
#
#     accuracy                           0.62       181
#    macro avg       0.68      0.60      0.56       181
# weighted avg       0.67      0.62      0.57       181

# %% [markdown]
# ### 5.	Create a neural network using pytorch to predict the same result as question 3.

# %% [markdown]
# Now to try the same with pytorch

# %%
import torch

X = df.drop('class', axis=1).values
y = df['class'].values

# Split into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42, stratify=y)

# Standardize
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
import torch.nn as nn
import torch.nn.functional as F #where the activation functions are

#create tensors = matrices
X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)

y_train = torch.LongTensor(y_train)
y_test = torch.LongTensor(y_test)

# %%
#artificial neural network
class ANN_Model(nn.Module):
    def __init__(self, input_features=279,hidden1=20,hidden2=20,out_features=2):
        super().__init__() #super is a computed indirect reference. So, it isolates changes
        # and makes sure that children in the layers of multiple inheritence are calling
        #the right parents
        self.layer_1_connection = nn.Linear(input_features, hidden1)
        self.layer_2_connection = nn.Linear(hidden1, hidden2)
        self.out = nn.Linear(hidden2, out_features)
        
    def forward(self, x):
        #apply activation functions
        x = F.relu(self.layer_1_connection(x))
        x = F.relu(self.layer_2_connection(x))
        x = self.out(x)
        return x

# %%
torch.manual_seed(42)

#create instance of model
ann = ANN_Model()

#loss function
loss_function = nn.CrossEntropyLoss()

#optimizer
optimizer = torch.optim.Adam(ann.parameters(),lr=.0001) #lr is learning rate - play around with

# %%
#run model through multiple epochs/iterations
final_loss = []
n_epochs = 500
for epoch in range(n_epochs):
    y_pred = ann.forward(X_train)
    loss = loss_function(y_pred, y_train)
    final_loss.append(loss)
    
    optimizer.zero_grad() #zero the gradient before running backwards propagation
    loss.backward() 
    optimizer.step() #perform one optimization step each epoch

# %%
# predictions
y_pred = []

with torch.no_grad():
    for i, data in enumerate(X_test):
        prediction = ann(data)
        y_pred.append(prediction.argmax())

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.80        74
#            1       0.77      0.71      0.74        62
#
#     accuracy                           0.77       136
#    macro avg       0.77      0.77      0.77       136
# weighted avg       0.77      0.77      0.77       136

# %% [markdown]
# ### 6.	Compare the performance of the neural networks to the other model you created. Which performed better? Why do you think that is?

# %% [markdown]
# | Model | Accuracy |
# | :--- | :--- |
# | keras |.79|
# | pytorch |.77|
# | KNN |.62|

# %% [markdown]
# Both keras and pytorch performed better than KNN, with kera doing the best of the 3. I tried various things to get KNN to perform better but could not find the right settings that made any difference.
#
# A neural network can have hidden nodes for concepts, using these inputs to make the final decision.
#
# Whereas KNN and linear regression is based on more obvious facts, and not side effects. A neural network should be able to make more accurate predictions.

# %% [markdown]
# ![Intro-deep-learn.PNG](attachment:Intro-deep-learn.PNG)
